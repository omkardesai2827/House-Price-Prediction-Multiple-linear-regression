# %%
import pandas as pd
df=pd.read_csv("House_price.csv")
df
# Out:
#       Avg. Area Income  House Age  Number of Rooms  Number of Bedrooms  \
# 0          79545.45857   5.682861         7.009188                4.09
# 1          79248.64245   6.002900         6.730821                3.09
# 2          61287.06718   5.865890         8.512727                5.13
# 3          63345.24005   7.188236         5.586729                3.26
# 4          59982.19723   5.040555         7.839388                4.23
# ...                ...        ...              ...                 ...
# 4543       84556.63627   5.092459         6.723412                2.42
# 4544       82732.98111   5.332712         6.198476                3.49
# 4545       65694.05127   6.436741         6.704929                3.14
# 4546       76061.35071   7.148713         7.546066                6.30
# 4547       66935.47508   6.376390         8.513826                5.47
#
#       Area Population         Price  \
# 0         23086.80050  1.059034e+06
# 1         40173.07217  1.505891e+06
# ...

# %%
pip install pycaret
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 481.8/481.8 kB 9.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 150.0/150.0 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.2/81.2 kB 9.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.5/212.5 kB 22.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 11.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.8/105.8 kB 11.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 4.1 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.9/16.9 MB 30.4 MB/s eta 0:00:00
# ...

# %%
import pycaret

# %%
from pycaret.regression import *

# %%
s=setup(data=df,target="Price",session_id=123)
# Out:
# <style type="text/css">
# #T_04e7e_row9_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_04e7e" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04e7e_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_04e7e_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04e7e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04e7e_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_04e7e_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_04e7e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_04e7e_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_04e7e_row1_col1" class="data row1 col1" >Price</td>
#     </tr>
#     <tr>
#       <th id="T_04e7e_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best=compare_models()
# Out:
# <style type="text/css">
# #T_ecf1a th {
#   text-align: left;
# }
# ...

# %%
# as you can ridge and lasso are the best among
# but there was multicollinearity in our model hence we use ridge regression
